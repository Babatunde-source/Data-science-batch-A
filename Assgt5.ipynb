# %% [markdown]
# <a href="https://colab.research.google.com/github/Babatunde-source/Data-science-batch-A/blob/main/Assgt5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
# randomly display five rows
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 128             8.0              0.59         0.16  ...       0.92     10.5        7
# 327            10.3              0.44         0.50  ...       0.83     11.5        5
# 741             9.2              0.53         0.24  ...       0.57      9.5        5
# 1520            6.5              0.53         0.06  ...       0.83     10.3        6
# 795            10.8              0.89         0.30  ...       1.18     10.2        5
#
# [5 rows x 12 columns]

# %%
# check for missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# A simple line plot using seaborn
sns.lineplot(data= df, x="alcohol", y="quality")

# %%
# list columns
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# simple line plot with grid lines using seaborn
sns.set_theme(style="darkgrid")
sns.lineplot(
    data=df, x="citric acid", y="quality"
    )

# %%
df_wh = pd.read_csv('/content/weight-height - Copy.csv')

# %%
# randomly display five rows
df_wh.sample(5)
# Out:
#       Gender     Height      Weight
# 1666    Male  68.846310  174.887367
# 5379  Female  57.882978  110.725972
# 4139    Male  70.201890  192.528057
# 8731  Female  59.556908  116.191983
# 7992  Female  61.076542  131.336444

# %%
# check for missing values
df_wh.isnull().sum()
# Out:
# Gender    0
# Height    2
# Weight    3
# dtype: int64

# %%
# drop missing value
df_wh= df_wh.dropna()
# convert float data types to integer
df_wh.Weight= df_wh['Weight'].astype('int64')
df_wh.Height= df_wh['Height'].astype('int64')

# %%
# a scatterplot using seaborn
sns.relplot(x="Height", y="Weight", hue="Gender", data=df_wh)

# %%
# statistical detail i=of the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
# a simple box plot using seaborn
sns.boxplot(y=df["quality"])

# %%
# using seaborn for many boxplot on chart
sns.boxplot(x= "Height", y="Weight", hue="Gender", data=df_wh)

# %%
# using matplotlib to plot histogram
plt.hist(x=df["alcohol"])
plt.title('Histogram distribution for alcohol content')
plt.show()

# %%
# using matplotlib to plot histogram of just two features
plt.hist(x=df_wh['Gender'])
plt.title('Histogram distribution for Gender')
plt.show()

# %%
# using seaborn and matplotlib to plot a histogram to two features
sns.histplot(x=df_wh["Gender"], y=df_wh["Weight"])
plt.xlabel('Gender')
plt.ylabel('Weight')
plt.title('Histogram distribution for Weight')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# using the pairplot api from seaborn to show the relationship between the features of the dataset
sns.pairplot(df_wh)

# %%
# Histogram plot with 30 bins using seaborn
sns.histplot(data=df_wh, x="Weight", bins=30)

# %%
# Histogram plot with kernel density using seaborn
sns.histplot(data=df_wh, x="Height", bins=30, kde=True)

# %%
#Assignment
url="https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv"
df1= pd.read_csv(url)

# %%
df1.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 144           6.7          3.3           5.7          2.5   virginica
# 26            5.0          3.4           1.6          0.4      setosa
# 65            6.7          3.1           4.4          1.4  versicolor
# 78            6.0          2.9           4.5          1.5  versicolor
# 40            5.0          3.5           1.3          0.3      setosa

# %%
df1.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df1.sepal_length= df1['sepal_length'].astype('int64')
df1.sepal_width= df1['sepal_width'].astype('int64')
df1.petal_length= df1['petal_length'].astype('int64')
df1.petal_width= df1['petal_width'].astype('int64')

# %%
sns.relplot(x="sepal_length",y="sepal_width",hue="species",data=df1)

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.386667     2.646667      3.306667     0.860000
# std        0.841752     0.532648      1.772068     0.714472
# min        4.000000     2.000000      1.000000     0.000000
# 25%        5.000000     2.000000      1.000000     0.000000
# 50%        5.000000     3.000000      4.000000     1.000000
# 75%        6.000000     3.000000      5.000000     1.000000
# max        7.000000     4.000000      6.000000     2.000000

# %%
sns.boxplot(y=df1["sepal_length"])

# %%
# using seaborn for many boxplot on a chart
sns.boxplot(x="sepal_length",y="sepal_width",hue="species",data=df1)

# %%
# using matplotlib to plot histogram
plt.hist(x=df1['petal_length'])
plt.title('Histogram distribution of petal length')
plt.show()

# %%
# using matplotlib to plot histogram of three features
plt.hist(x=df1['species'])
plt.title('Histogram distribution for species')
plt.show()

# %%
# using matplotlib and seaborn to plot a histogram of three features
sns.histplot( x=df1["species"], y=df1["sepal_width"] )
plt.xlabel('species')
plt.ylabel('sepal_width')
plt.title('Histogram distribution for sepal_width')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.pairplot(df1)

# %%
# Histogram plot with 3 bins using seaborn
sns.histplot(data=df1, x= "sepal_width", bins=3)

# %%
# Histogram plot with kernel density using seaborn
sns.histplot(data=df1, x="sepal_length", bins=3, kde=True)
